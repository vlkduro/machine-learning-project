# %% [markdown]
# ## AI28 - Projet - Prédiction du niveau de revenus.

# %%
# OS
import sys


# WARNINGS
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('error', category=DeprecationWarning)

# NUMPY
import numpy as np

# STATS
import scipy.stats as stats
from scipy.stats import norm, skew

# MATPLOTLIB
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('fivethirtyeight') 

params = {'axes.labelsize': 8, # 12
          'font.size': 8, # 12
          'legend.fontsize': 8, # 12
          'xtick.labelsize': 8, # 10
          'ytick.labelsize': 8, # 10
          'text.usetex': True,
          'figure.figsize': (10, 8)}
plt.rcParams.update(params)


# PANDAS
import pandas as pd 
pd.set_option("display.max_rows", None, "display.max_columns", None) 

# SEABORN 
import seaborn as sns
# sns.set_context("poster")
# sns.set_style("ticks")

# SCHIKIT-LEARN: PRE-PROCESSING
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # Encodage des variables catégorielles ordinales
from sklearn.preprocessing import LabelBinarizer, OneHotEncoder # Encodage des variables catégorielles nominales
from sklearn.preprocessing import StandardScaler # Standardisation des variables numériques
from sklearn.preprocessing import MinMaxScaler # Normalisation MinMax
from sklearn.preprocessing import RobustScaler
from sklearn.impute import SimpleImputer # Imputation
from sklearn.impute import KNNImputer 


# SCHIKIT-LEARN: MODELES
from sklearn import linear_model # Classe Modèle linéaire 
from sklearn.linear_model import LinearRegression 
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso 
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR 
from sklearn.neighbors import KNeighborsClassifier

# SCHIKIT-LEARN: VALIDATION CROISEE + OPTIMISATION
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score # Validation croisée pour comparaison entre modèles
from sklearn.model_selection import validation_curve # Courbe de validation: visualiser les scores lors du choix d'un hyperparamétre
from sklearn.model_selection import GridSearchCV # Tester plusieurs hyperparamètres
from sklearn.model_selection import RandomizedSearchCV # Tester plusieurs hyperparamètres
from sklearn.model_selection import learning_curve # Courbe d'apprentissage: visualisation des scores du train et du validation sets en fonction des quantités des données
import optuna
from optuna.trial import FixedTrial
 
## EVALUATION

from sklearn.metrics import r2_score, accuracy_score, recall_score, f1_score
from sklearn.metrics import mean_absolute_error #  MAE
from sklearn.metrics import mean_squared_error  # RMSE
from sklearn.metrics import median_absolute_error # Erreur de la médiane absolue

# SCHIKIT-LEARN: PIPELINE AND TRANSFORMATEUR
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

# SOURCE DATA
from ucimlrepo import fetch_ucirepo

# %%
# Utilisation des commandes fournies par UCI

# Télécharger le jeu de données 
data_adult = fetch_ucirepo(id=2)

# %%
# data (as pandas dataframes) 
x = data_adult.data.features # variables explicatives
y = data_adult.data.targets # variables cibles

# %%
# metadata 
print(data_adult.metadata)
# Out:
# {'uci_id': 2, 'name': 'Adult', 'repository_url': 'https://archive.ics.uci.edu/dataset/2/adult', 'data_url': 'https://archive.ics.uci.edu/static/public/2/data.csv', 'abstract': 'Predict whether annual income of an individual exceeds $50K/yr based on census data. Also known as "Census Income" dataset. ', 'area': 'Social Science', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 48842, 'num_features': 14, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Age', 'Income', 'Education Level', 'Other', 'Race', 'Sex'], 'target_col': ['income'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1996, 'last_updated': 'Tue Sep 24 2024', 'dataset_doi': '10.24432/C5XW20', 'creators': ['Barry Becker', 'Ronny Kohavi'], 'intro_paper': None, 'additional_info': {'summary': "Extraction was done by Barry Becker from the 1994 Census database.  A set of reasonably clean records was extracted using the following conditions: ((AAGE>16) && (AGI>100) && (AFNLWGT>1)&& (HRSWK>0))\n\nPrediction task is to determine whether a person's income is over $50,000 a year.\n", 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'Listing of attributes:\r\n\r\n>50K, <=50K.\r\n\r\nage: continuous.\r\nworkclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.\r\nfnlwgt: continuous.\r\neducation: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.\r\neducation-num: continuous.\r\nmarital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.\r\noccupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.\r\nrelationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.\r\nrace: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.\r\nsex: Female, Male.\r\ncapital-gain: continuous.\r\ncapital-loss: continuous.\r\nhours-per-week: continuous.\r\nnative-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.', 'citation': None}}

# %%
# variable information 
print(data_adult.variables)
# Out:
#               name     role         type      demographic  \
# 0              age  Feature      Integer              Age
# 1        workclass  Feature  Categorical           Income
# 2           fnlwgt  Feature      Integer             None
# 3        education  Feature  Categorical  Education Level
# 4    education-num  Feature      Integer  Education Level
# 5   marital-status  Feature  Categorical            Other
# 6       occupation  Feature  Categorical            Other
# 7     relationship  Feature  Categorical            Other
# 8             race  Feature  Categorical             Race
# 9              sex  Feature       Binary              Sex
# 10    capital-gain  Feature      Integer             None
# 11    capital-loss  Feature      Integer             None
# 12  hours-per-week  Feature      Integer             None
# 13  native-country  Feature  Categorical            Other
# 14          income   Target       Binary           Income
#
#                                           description units missing_values
# 0                                                 N/A  None             no
# 1   Private, Self-emp-not-inc, Self-emp-inc, Feder...  None            yes
# 2                                                None  None             no
# 3    Bachelors, Some-college, 11th, HS-grad, Prof-...  None             no
# 4                                                None  None             no
# 5   Married-civ-spouse, Divorced, Never-married, S...  None             no
# 6   Tech-support, Craft-repair, Other-service, Sal...  None            yes
# 7   Wife, Own-child, Husband, Not-in-family, Other...  None             no
# 8   White, Asian-Pac-Islander, Amer-Indian-Eskimo,...  None             no
# 9                                       Female, Male.  None             no
# 10                                               None  None             no
# 11                                               None  None             no
# 12                                               None  None             no
# 13  United-States, Cambodia, England, Puerto-Rico,...  None            yes
# 14                                       >50K, <=50K.  None             no

# %% [markdown]
# ## Analyse exploratoire des données
#
# Pour réaliser l'AED, nous utilisons les données des fichiers téléchargés depuis le site web.

# %%
df_adult = pd.read_csv("./Data/adult.data", header=None)

# %%
isinstance(df_adult, pd.DataFrame)
# Out:
# True

# %% [markdown]
# Le fichier ne contient pas les noms des colonnes. Nous les ajoutons dans le dataframe adult.

# %%
adult_columns = data_adult.variables['name']

df_adult.columns = adult_columns

df_adult.head()
# Out:
# name  age          workclass  fnlwgt   education  education-num  \
# 0      39          State-gov   77516   Bachelors             13
# 1      50   Self-emp-not-inc   83311   Bachelors             13
# 2      38            Private  215646     HS-grad              9
# 3      53            Private  234721        11th              7
# 4      28            Private  338409   Bachelors             13
#
# name       marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
#
# name      sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0        Male          2174             0              40   United-States
# 1        Male             0             0              13   United-States
# 2        Male             0             0              40   United-States
# 3        Male             0             0              40   United-States
# 4      Female             0             0              40            Cuba
#
# name  income
# 0      <=50K
# 1      <=50K
# 2      <=50K
# 3      <=50K
# 4      <=50K

# %%
df_adult.shape
# Out:
# (32561, 15)

# %%
df_adult.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object', name='name')

# %%
df_adult.describe()
# Out:
# name            age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
# name   hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df_adult.isna().sum()
# Out:
# name
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df_adult = df_adult.drop_duplicates()
df_adult[df_adult.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, income]
# Index: []

# %%
(df_adult["education"].unique())
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
df_adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32537 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       32537 non-null  object
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  object
#  4   education-num   32537 non-null  int64
#  5   marital-status  32537 non-null  object
#  6   occupation      32537 non-null  object
#  7   relationship    32537 non-null  object
#  8   race            32537 non-null  object
#  9   sex             32537 non-null  object
#  10  capital-gain    32537 non-null  int64
#  11  capital-loss    32537 non-null  int64
#  12  hours-per-week  32537 non-null  int64
#  13  native-country  32537 non-null  object
#  14  income          32537 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 4.0+ MB

# %% [markdown]
# Problème : La description des données indique qu'elles contiennent des valeurs inconnues. Ces valeurs ne sont pas en NaN ou null. Nous pouvons déjà remarquer la présence de '?' en leur lieu et place.
#
# ## Traitement des données
#
# ### Analyse des traitements à réaliser

# %%
df_adult = df_adult.replace('\?', np.nan, regex=True)
sns.heatmap(df_adult.isna(), cbar=False, cmap='viridis')
print(f"Nombre de valeurs manquantes : {df_adult.isna().sum()}")
# Out:
# Nombre de valeurs manquantes : name
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     582
# income               0
# dtype: int64

# %%
tmp_df=df_adult.drop_duplicates(['education','education-num'])[['education','education-num']]
print(tmp_df.sort_values('education-num', ascending=True))
# Out:
# name      education  education-num
# 224       Preschool              1
# 160         1st-4th              2
# 56          5th-6th              3
# 15          7th-8th              4
# 6               9th              5
# 77             10th              6
# 3              11th              7
# 415            12th              8
# 2           HS-grad              9
# 10     Some-college             10
# 14        Assoc-voc             11
# 13       Assoc-acdm             12
# 0         Bachelors             13
# 5           Masters             14
# 52      Prof-school             15
# 20        Doctorate             16

# %%
wrkclass_proportion = df_adult["workclass"].value_counts(dropna=False) / df_adult.shape[0]
print("workclass : ", wrkclass_proportion.idxmax(), f"{wrkclass_proportion.max() * 100:.2f}% ({len(wrkclass_proportion)} valeurs uniques)")
occupation_proportion = df_adult["occupation"].value_counts(dropna=False) / df_adult.shape[0]
print("occupation : ", occupation_proportion.idxmax(), f"{occupation_proportion.max() * 100:.2f}% ({len(occupation_proportion)} valeurs uniques)")
native_country_proportion = df_adult["native-country"].value_counts(dropna=False) / df_adult.shape[0]
print("native_country : ", native_country_proportion.idxmax(), f"{native_country_proportion.max() * 100:.2f}% ({len(native_country_proportion)} valeurs uniques)")
income_proportion = df_adult["income"].value_counts(dropna=False) / df_adult.shape[0]
print("income : ", income_proportion.idxmax(), f"{income_proportion.max() * 100:.2f}% ({len(income_proportion)} valeurs uniques)")
# Out:
# workclass :   Private 69.68% (9 valeurs uniques)
# occupation :   Prof-specialty 12.71% (15 valeurs uniques)
# native_country :   United-States 89.60% (42 valeurs uniques)
# income :   <=50K 75.91% (2 valeurs uniques)

# %% [markdown]
#  ### Creation de la fonction de traitement des données

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

def treat_df(df, preprocessor = None):
    df_new = df.copy()
    # Remplacement de la valeur '?' par NaN
    df_new = df_new.replace('\?', np.nan, regex=True)
    # Remplacement des valeurs manquantes par les valeurs les plus fréquentes, les seules variables concernées sont workclass, occupation et native-country
    for col in ["workclass", "occupation", "native-country"]:
        df_new[col].fillna(df_new[col].mode()[0], inplace=True)

    # Retrait de la variable education (redondance et deja encodée de manière ordinale par education-num)
    print(df_new.columns)
    df_new.drop('education', inplace=True, axis=1)


    # Selection des different types de variables
    categorical_columns = df_new.select_dtypes(include=['object']).columns
    numerical_columns = df_new.select_dtypes(include=['number']).columns
    # Retrait de la variable cible des colonnes categorielles à traiter
    categorical_columns = categorical_columns.drop('income')
    # Retrait de la variable education-num des colonnes numeriques à traiter
    numerical_columns = numerical_columns.drop('education-num')

    # Pretraitement des features
    if preprocessor is None:
        preprocessor = ColumnTransformer(
            transformers = [
                ('numerical', StandardScaler(), numerical_columns),
                # La feature education est ordonnée
                ('categorical', OneHotEncoder(sparse_output=False), categorical_columns),
                ('education-num', "passthrough", ['education-num'])
            ]
        )
        preprocessor.fit(df_new.drop("income", axis=1))
    features_processed = preprocessor.transform(df_new.drop('income', axis=1))
    column_names = (
        preprocessor.named_transformers_['numerical'].get_feature_names_out(numerical_columns).tolist() +
        preprocessor.named_transformers_['categorical'].get_feature_names_out(categorical_columns).tolist() +
        preprocessor.named_transformers_['education-num'].get_feature_names_out(['education-num']).tolist()
    )
    df_processed = pd.DataFrame(features_processed, columns=column_names)

    # Pretraitement de la variable cible, (0: <=50K, 1: >50K)
    label_encoder = LabelEncoder()
    df_processed['income'] = label_encoder.fit_transform(df_new['income'])
    print(df_new['income'].value_counts())
    print(df_processed['income'].value_counts())
    return df_processed, preprocessor

# %% [markdown]
# ## Modele de prediction
#
# ### Préparation des modèles
#
# Nous comptons utiliser la librairie `optuna` pour l'optimisation des hyperparamètres. Afin de permettre une comparaison facile des modèles entre eux, nous préparons des fonctions pour chaque modèle que nous souhaitons optimiser.

# %%
from sklearn.metrics import confusion_matrix

# Creation des sets de train et validation (repartition 80/20 pour train/validation)
df_adult_new, fitted_preprocessor = treat_df(df_adult, None)
X_train, X_val, y_train, y_val = train_test_split(df_adult_new.drop(columns=["income"]), df_adult_new["income"], test_size=0.2, random_state=69)

def eval_model(model, X_test, y_test):
    """
    :return: accuracy, recall, neg_recall, f1, mae, rmse, accuracy_neg_pred, accuracy_pos_pred
    """
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    neg_recall = recall_score(y_test, y_pred, pos_label=0)
    f1 = f1_score(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred)
    print(f"Accuracy : {accuracy:.4f} (the higher the better)")
    print(f"Recall : {recall:.4f} (the higher the better) (best for us)")
    print(f"Negative recall : {neg_recall:.4f} (the lower the better)")
    print(f"F1 : {f1:.4f} (the higher the better)")
    print(f"MAE : {mae:.4f} (the lower the better)")
    print(f"RMSE : {rmse:.4f} (the lower the better)")
    return accuracy, recall, neg_recall, f1, mae, rmse
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object', name='name')
# income
# <=50K    24698
# >50K      7839
# Name: count, dtype: int64
# income
# 0    24698
# 1     7839
# Name: count, dtype: int64

# %% [markdown]
# ### Arbre de décision

# %%
from sklearn.tree import DecisionTreeClassifier

def opt_decision_tree(trial):
    max_depth = trial.suggest_int('max_depth', 2, 32)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 4)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2'])
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])
    return DecisionTreeClassifier(
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        criterion=criterion
    )

def obj_decision_tree(trial):
    model = opt_decision_tree(trial)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    recall = recall_score(y_val, y_pred)
    return recall

# %% [markdown]
# ### Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

def opt_random_forest(trial):
    rf_max_depth = trial.suggest_int('rf_max_depth', 2, 32)
    rf_min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 10)
    rf_min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 4)
    rf_max_features = trial.suggest_categorical('rf_max_features', ['sqrt', 'log2'])
    rf_criterion = trial.suggest_categorical('rf_criterion', ['gini', 'entropy'])
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 50, 200)
    return RandomForestClassifier(
        max_depth=rf_max_depth,
        min_samples_split=rf_min_samples_split,
        min_samples_leaf=rf_min_samples_leaf,
        max_features=rf_max_features,
        criterion=rf_criterion,
        n_estimators=rf_n_estimators
    )

def obj_random_forest(trial):
    model = opt_random_forest(trial)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    recall = recall_score(y_val, y_pred)
    return recall

# %% [markdown]
# ### Regression logistique

# %%
from sklearn.linear_model import LogisticRegression

def opt_logistic_regression(trial):
    solver = trial.suggest_categorical('solver', ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'])

    # Filter penalties based on the solver
    penalty = "l2"  # Default penalty if an error occurs
    if solver in ['newton-cg', 'lbfgs', 'sag']:
        penalty = trial.suggest_categorical('penalty', ['l2', None])
    elif solver == 'liblinear':
        penalty = trial.suggest_categorical('penalty-liblinear', ['l1', 'l2'])
    elif solver == 'saga':
        penalty = trial.suggest_categorical('penalty-saga', ['l1', 'l2', 'elasticnet', None])
    # l1_ratio est utlisé pour l'elasticnet
    l1_ratio = trial.suggest_float('l1_ratio', 0.1, 0.5, log=True)
    C = trial.suggest_float('C', 0.01, 10.0, log=True)
    max_iter = trial.suggest_int('max_iter', 50, 500)
    return LogisticRegression(
        penalty=penalty,
        C=C,
        solver=solver,
        max_iter=max_iter,
        l1_ratio=l1_ratio,
    )

def obj_logistic_regression(trial):
    model = opt_logistic_regression(trial)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    recall = recall_score(y_val, y_pred)
    return recall

# %% [markdown]
# ### AdaBoosting

# %%
from sklearn.ensemble import AdaBoostClassifier

def opt_adaboost(trial):
    base_estimator = trial.suggest_categorical('base_estimator', ['DecisionTree', 'RandomForest'])
    base_estimator_obj = None
    if base_estimator == 'DecisionTree':
        base_estimator_obj = opt_decision_tree(trial)
    elif base_estimator == 'RandomForest':
        base_estimator_obj = opt_random_forest(trial)

    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3)

    return AdaBoostClassifier(
        estimator=base_estimator_obj,
        n_estimators=n_estimators,
        learning_rate=learning_rate
    )

def obj_adaboost(trial):
    model = opt_adaboost(trial)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    recall = recall_score(y_val, y_pred)
    return recall

# %% [markdown]
# ### Gradient boosting

# %%
from xgboost import XGBClassifier

def opt_xgb(trial):
    max_depth = trial.suggest_int('max_depth', 2, 32)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 4)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2'])
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])
    n_estimators = trial.suggest_int('n_estimators', 50, 200)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.3)
    return XGBClassifier(
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        criterion=criterion,
        n_estimators=n_estimators,
        learning_rate=learning_rate
    )

def obj_xgb(trial):
    model = opt_xgb(trial)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    recall = recall_score(y_val, y_pred)
    return recall

# %% [markdown]
# ### Stacking RF-XGB

# %%
from sklearn.ensemble import StackingClassifier

def opt_stacking_rf_xgb(trial):
    rf_max_depth = trial.suggest_int('rf_max_depth', 2, 32)
    rf_min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 10)
    rf_min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 4)
    rf_max_features = trial.suggest_categorical('rf_max_features', ['sqrt', 'log2'])
    rf_criterion = trial.suggest_categorical('rf_criterion', ['gini', 'entropy'])
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 50, 200)

    xgb_max_depth = trial.suggest_int('xgb_max_depth', 2, 32)
    xgb_min_samples_split = trial.suggest_int('xgb_min_samples_split', 2, 10)
    xgb_min_samples_leaf = trial.suggest_int('xgb_min_samples_leaf', 1, 4)
    xgb_max_features = trial.suggest_categorical('xgb_max_features', ['sqrt', 'log2'])
    xgb_criterion = trial.suggest_categorical('xgb_criterion', ['gini', 'entropy'])
    xgb_n_estimators = trial.suggest_int('xgb_n_estimators', 50, 200)

    return StackingClassifier(
        estimators=[
            ('rf', RandomForestClassifier(
                max_depth=rf_max_depth,
                min_samples_split=rf_min_samples_split,
                min_samples_leaf=rf_min_samples_leaf,
                max_features=rf_max_features,
                criterion=rf_criterion,
                n_estimators=rf_n_estimators
            )),
            ('xgb', XGBClassifier(
                max_depth=xgb_max_depth,
                min_samples_split=xgb_min_samples_split,
                min_samples_leaf=xgb_min_samples_leaf,
                max_features=xgb_max_features,
                criterion=xgb_criterion,
                n_estimators=xgb_n_estimators
            ))
        ],
        final_estimator=XGBClassifier(random_state=69)
    )

def obj_stacking_rf_xgb(trial):
    model = opt_stacking_rf_xgb(trial)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    recall = recall_score(y_val, y_pred)
    return recall

# %% [markdown]
# ## KNN (K-Nearest Neighbors)

# %%
def opt_knn(trial):
    n_neighbors = trial.suggest_int('n_neighbors', 1, 20)
    weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
    algorithm = trial.suggest_categorical('algorithm', ['auto', 'ball_tree', 'kd_tree', 'brute'])
    leaf_size = trial.suggest_int('leaf_size', 10, 50)
    p = trial.suggest_int('p', 1, 2)

    return make_pipeline(
        StandardScaler(),  # très important pour KNN
        KNeighborsClassifier(
            n_neighbors=n_neighbors,
            weights=weights,
            algorithm=algorithm,
            leaf_size=leaf_size,
            p=p
        )
    )

def obj_knn(trial):
    model = opt_knn(trial)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    recall = recall_score(y_val, y_pred)
    return recall

# %% [markdown]
# ## Classification de Bayes

# %%
from sklearn.naive_bayes import GaussianNB

def opt_bayes(trial):
    var_smoothing = trial.suggest_float('var_smoothing', 1e-11, 1e-6, log=True)
    return GaussianNB(var_smoothing=var_smoothing)

def obj_bayes(trial):
    model = opt_bayes(trial)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    recall = recall_score(y_val, y_pred)
    return recall

# %% [markdown]
# ### Machine à vecteurs de support (SVM)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier

def opt_svm(trial):
    C = trial.suggest_float('C', 0.01, 10.0, log=True)
    kernel = trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid'])
    gamma = trial.suggest_categorical('gamma', ['scale', 'auto'])
    degree = trial.suggest_int('degree', 2, 5) if kernel == 'poly' else 3  # Seulement pour le kernel poly
    class_weight = trial.suggest_categorical('class_weight', [None, 'balanced'])
    n_estimators = trial.suggest_int('n_estimators', 10, 200)
    # On wrap autour du BaggingClassifier pour accelerer l'entrainement et améliorer le modèle
    return BaggingClassifier(SVC(
        C=C,
        kernel=kernel,
        gamma=gamma,
        degree=degree,
        class_weight=class_weight,
        probability=True  # Active les estimations en probabilités pour le courbe ROC
    ), n_estimators=n_estimators, max_samples=1.0 / n_estimators)

def obj_svm(trial):
    model = opt_svm(trial)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    recall = recall_score(y_val, y_pred)
    return recall

# %% [markdown]
# ### KMeans

# %%
from sklearn.cluster import KMeans

def opt_kmeans(trial):
    # n_clusters = trial.suggest_int('n_clusters', 2, 20)
    init = trial.suggest_categorical('init', ['k-means++', 'random'])
    n_init = trial.suggest_int('n_init', 10, 50)
    max_iter = trial.suggest_int('max_iter', 100, 500)
    tol = trial.suggest_float('tol', 1e-6, 1e-2, log=True)
    return KMeans(
        n_clusters=2,
        init=init,
        n_init=n_init,
        max_iter=max_iter,
        tol=tol,
    )

def obj_kmeans(trial):
    model = opt_kmeans(trial)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    recall = recall_score(y_val, y_pred)
    return recall

# %% [markdown]
# ### Stacking Bayes-XGB

# %%
from sklearn.ensemble import StackingClassifier

def opt_stacking_bayes_xgb(trial):
    bayes_var_smoothing = trial.suggest_float('bayes_var_smoothing', 1e-11, 1e-6, log=True)

    xgb_max_depth = trial.suggest_int('xgb_max_depth', 2, 32)
    xgb_min_samples_split = trial.suggest_int('xgb_min_samples_split', 2, 10)
    xgb_min_samples_leaf = trial.suggest_int('xgb_min_samples_leaf', 1, 4)
    xgb_max_features = trial.suggest_categorical('xgb_max_features', ['sqrt', 'log2'])
    xgb_criterion = trial.suggest_categorical('xgb_criterion', ['gini', 'entropy'])
    xgb_n_estimators = trial.suggest_int('xgb_n_estimators', 50, 200)

    return StackingClassifier(
        estimators=[
            ('bayes', GaussianNB(
                var_smoothing=bayes_var_smoothing,
            )),
            ('xgb', XGBClassifier(
                max_depth=xgb_max_depth,
                min_samples_split=xgb_min_samples_split,
                min_samples_leaf=xgb_min_samples_leaf,
                max_features=xgb_max_features,
                criterion=xgb_criterion,
                n_estimators=xgb_n_estimators
            ))
        ],
        final_estimator=XGBClassifier(random_state=69)
    )

def obj_stacking_bayes_xgb(trial):
    model = opt_stacking_bayes_xgb(trial)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    recall = recall_score(y_val, y_pred)
    return recall

# %% [markdown]
# ## Optimisation des hyperparamètres pour differents classifieurs avec `optuna`
#
# On optimise les differents hyperparamètres pour chaque classifieur et on stocke le meilleur modele de chaque classifieur dans un dictionnaire pour les évaluer et comparer ensuite.

# %%
best_models = {}

def get_best_model_for_classifier(name, opt_obj, opt_func):
    study = optuna.create_study(direction='maximize', study_name=f"{name} - Adult Income Prediction")
    study.optimize(opt_obj, n_trials=150, timeout=900)
    print(f"{name} Best hyperparameters: ", study.best_params)
    return opt_func(FixedTrial(study.best_params))

# DecisionTree
best_models["DecisionTree"] = get_best_model_for_classifier("DecisionTree", obj_decision_tree, opt_decision_tree)
# RandomForest
best_models["RandomForest"] = get_best_model_for_classifier("RandomForest", obj_random_forest, opt_random_forest)
# LogisticRegression
best_models["LogisticRegression"] = get_best_model_for_classifier("LogisticRegression", obj_logistic_regression, opt_logistic_regression)
# AdaBoosting
best_models["AdaBoosting"] = get_best_model_for_classifier("AdaBoosting", obj_adaboost, opt_adaboost)
# XGBoosting
best_models["XGBoosting"] = get_best_model_for_classifier("XGBoosting", obj_xgb, opt_xgb)
# Stacking RF-SGB
best_models["Stacking RF-XGB"] = get_best_model_for_classifier("Stacking RF-XGB", obj_stacking_rf_xgb, opt_stacking_rf_xgb)
# KNN
best_models["KNN"] = get_best_model_for_classifier("KNN", obj_knn, opt_knn)
# NaiveBayes
best_models["NaiveBayes"] = get_best_model_for_classifier("NaiveBayes", obj_bayes, opt_bayes)
# SVM
best_models["SVM"] = get_best_model_for_classifier("SVM", obj_svm, opt_svm)
# KMean
best_models["KMeans"] = get_best_model_for_classifier("KMeans", obj_kmeans, opt_kmeans)
# Stacking Bayes-XGB
best_models["Stacking Bayes-XGB"] = get_best_model_for_classifier("Stacking Bayes-XGB", obj_stacking_bayes_xgb, opt_stacking_bayes_xgb)
# HDBSCAN - Ne marche pas pour nous
# best_models["HDBSCAN"] = get_best_model_for_classifier("HDBSCAN", opt_hdbscan)
# Out:
# [I 2025-06-21 19:50:08,881] A new study created in memory with name: DecisionTree - Adult Income Prediction
# [I 2025-06-21 19:50:08,940] Trial 0 finished with value: 0.4935064935064935 and parameters: {'max_depth': 22, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 0 with value: 0.4935064935064935.
# [I 2025-06-21 19:50:08,981] Trial 1 finished with value: 0.48794063079777367 and parameters: {'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 0 with value: 0.4935064935064935.
# [I 2025-06-21 19:50:08,996] Trial 2 finished with value: 0.5145330859616574 and parameters: {'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 'log2', 'criterion': 'entropy'}. Best is trial 2 with value: 0.5145330859616574.
# [I 2025-06-21 19:50:09,017] Trial 3 finished with value: 0.5219542362399505 and parameters: {'max_depth': 29, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 3 with value: 0.5219542362399505.
# [I 2025-06-21 19:50:09,040] Trial 4 finished with value: 0.6122448979591837 and parameters: {'max_depth': 25, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,056] Trial 5 finished with value: 0.3370439084724799 and parameters: {'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,075] Trial 6 finished with value: 0.48855905998763144 and parameters: {'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 'log2', 'criterion': 'entropy'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,094] Trial 7 finished with value: 0.5856524427952999 and parameters: {'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,109] Trial 8 finished with value: 0.47309833024118736 and parameters: {'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'criterion': 'entropy'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,134] Trial 9 finished with value: 0.5553494124922697 and parameters: {'max_depth': 21, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,166] Trial 10 finished with value: 0.5769944341372912 and parameters: {'max_depth': 31, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,196] Trial 11 finished with value: 0.6048237476808905 and parameters: {'max_depth': 27, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,226] Trial 12 finished with value: 0.5862708719851577 and parameters: {'max_depth': 26, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,240] Trial 13 finished with value: 0.0 and parameters: {'max_depth': 2, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,269] Trial 14 finished with value: 0.5349412492269635 and parameters: {'max_depth': 26, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,295] Trial 15 finished with value: 0.5324675324675324 and parameters: {'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,331] Trial 16 finished with value: 0.5547309833024119 and parameters: {'max_depth': 32, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,361] Trial 17 finished with value: 0.536178107606679 and parameters: {'max_depth': 26, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,388] Trial 18 finished with value: 0.5565862708719852 and parameters: {'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,413] Trial 19 finished with value: 0.5584415584415584 and parameters: {'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,440] Trial 20 finished with value: 0.5720470006184292 and parameters: {'max_depth': 24, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,469] Trial 21 finished with value: 0.5299938157081014 and parameters: {'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,500] Trial 22 finished with value: 0.5355596784168213 and parameters: {'max_depth': 28, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,532] Trial 23 finished with value: 0.533704390847248 and parameters: {'max_depth': 24, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,563] Trial 24 finished with value: 0.5541125541125541 and parameters: {'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 4 with value: 0.6122448979591837.
# [I 2025-06-21 19:50:09,592] Trial 25 finished with value: 0.6233766233766234 and parameters: {'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:09,626] Trial 26 finished with value: 0.551638837353123 and parameters: {'max_depth': 31, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:09,654] Trial 27 finished with value: 0.5782312925170068 and parameters: {'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:09,684] Trial 28 finished with value: 0.5782312925170068 and parameters: {'max_depth': 24, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:09,709] Trial 29 finished with value: 0.5306122448979592 and parameters: {'max_depth': 22, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:09,741] Trial 30 finished with value: 0.5807050092764379 and parameters: {'max_depth': 32, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:09,771] Trial 31 finished with value: 0.5788497217068646 and parameters: {'max_depth': 26, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:09,799] Trial 32 finished with value: 0.5219542362399505 and parameters: {'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:09,830] Trial 33 finished with value: 0.5800865800865801 and parameters: {'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:09,861] Trial 34 finished with value: 0.5701917130488559 and parameters: {'max_depth': 29, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:09,887] Trial 35 finished with value: 0.4873222016079159 and parameters: {'max_depth': 28, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:09,917] Trial 36 finished with value: 0.5405071119356833 and parameters: {'max_depth': 22, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:09,939] Trial 37 finished with value: 0.48855905998763144 and parameters: {'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:09,976] Trial 38 finished with value: 0.5398886827458256 and parameters: {'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,003] Trial 39 finished with value: 0.45021645021645024 and parameters: {'max_depth': 23, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,030] Trial 40 finished with value: 0.5021645021645021 and parameters: {'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,054] Trial 41 finished with value: 0.5145330859616574 and parameters: {'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,082] Trial 42 finished with value: 0.5281385281385281 and parameters: {'max_depth': 28, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,108] Trial 43 finished with value: 0.5813234384662956 and parameters: {'max_depth': 30, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,133] Trial 44 finished with value: 0.5200989486703772 and parameters: {'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,148] Trial 45 finished with value: 0.0 and parameters: {'max_depth': 2, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,183] Trial 46 finished with value: 0.549165120593692 and parameters: {'max_depth': 32, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,214] Trial 47 finished with value: 0.608534322820037 and parameters: {'max_depth': 27, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,246] Trial 48 finished with value: 0.5398886827458256 and parameters: {'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,275] Trial 49 finished with value: 0.5553494124922697 and parameters: {'max_depth': 27, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,306] Trial 50 finished with value: 0.5176252319109462 and parameters: {'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,337] Trial 51 finished with value: 0.5745207173778603 and parameters: {'max_depth': 26, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,369] Trial 52 finished with value: 0.5640074211502782 and parameters: {'max_depth': 29, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,391] Trial 53 finished with value: 0.2665429808286951 and parameters: {'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,422] Trial 54 finished with value: 0.4972170686456401 and parameters: {'max_depth': 31, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,449] Trial 55 finished with value: 0.5448361162646876 and parameters: {'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,477] Trial 56 finished with value: 0.5720470006184292 and parameters: {'max_depth': 28, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,508] Trial 57 finished with value: 0.5819418676561534 and parameters: {'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,538] Trial 58 finished with value: 0.6184291898577613 and parameters: {'max_depth': 23, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,571] Trial 59 finished with value: 0.5868893011750155 and parameters: {'max_depth': 23, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,606] Trial 60 finished with value: 0.5627705627705628 and parameters: {'max_depth': 23, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,643] Trial 61 finished with value: 0.5615337043908473 and parameters: {'max_depth': 24, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,674] Trial 62 finished with value: 0.5955473098330241 and parameters: {'max_depth': 21, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,708] Trial 63 finished with value: 0.5578231292517006 and parameters: {'max_depth': 21, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,740] Trial 64 finished with value: 0.564625850340136 and parameters: {'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,772] Trial 65 finished with value: 0.5701917130488559 and parameters: {'max_depth': 22, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,803] Trial 66 finished with value: 0.5194805194805194 and parameters: {'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,839] Trial 67 finished with value: 0.614100185528757 and parameters: {'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,871] Trial 68 finished with value: 0.5633889919604206 and parameters: {'max_depth': 25, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,903] Trial 69 finished with value: 0.5627705627705628 and parameters: {'max_depth': 20, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,937] Trial 70 finished with value: 0.6097711811997526 and parameters: {'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:10,972] Trial 71 finished with value: 0.5578231292517006 and parameters: {'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,004] Trial 72 finished with value: 0.5714285714285714 and parameters: {'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,038] Trial 73 finished with value: 0.5794681508967223 and parameters: {'max_depth': 26, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,070] Trial 74 finished with value: 0.5423623995052567 and parameters: {'max_depth': 22, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,097] Trial 75 finished with value: 0.525664811379097 and parameters: {'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,131] Trial 76 finished with value: 0.5299938157081014 and parameters: {'max_depth': 21, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,165] Trial 77 finished with value: 0.5528756957328386 and parameters: {'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,200] Trial 78 finished with value: 0.5670995670995671 and parameters: {'max_depth': 27, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,232] Trial 79 finished with value: 0.525664811379097 and parameters: {'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,264] Trial 80 finished with value: 0.5899814471243042 and parameters: {'max_depth': 18, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,294] Trial 81 finished with value: 0.5213358070500927 and parameters: {'max_depth': 17, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,328] Trial 82 finished with value: 0.5380333951762524 and parameters: {'max_depth': 18, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,356] Trial 83 finished with value: 0.5398886827458256 and parameters: {'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,386] Trial 84 finished with value: 0.5813234384662956 and parameters: {'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,417] Trial 85 finished with value: 0.5794681508967223 and parameters: {'max_depth': 21, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,482] Trial 86 finished with value: 0.531230674087817 and parameters: {'max_depth': 23, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,521] Trial 87 finished with value: 0.5528756957328386 and parameters: {'max_depth': 26, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,552] Trial 88 finished with value: 0.5534941249226963 and parameters: {'max_depth': 30, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,583] Trial 89 finished with value: 0.562152133580705 and parameters: {'max_depth': 22, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,616] Trial 90 finished with value: 0.5398886827458256 and parameters: {'max_depth': 28, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,649] Trial 91 finished with value: 0.562152133580705 and parameters: {'max_depth': 24, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,684] Trial 92 finished with value: 0.5219542362399505 and parameters: {'max_depth': 23, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,717] Trial 93 finished with value: 0.6072974644403216 and parameters: {'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,749] Trial 94 finished with value: 0.5677179962894249 and parameters: {'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,780] Trial 95 finished with value: 0.5473098330241187 and parameters: {'max_depth': 26, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,814] Trial 96 finished with value: 0.6029684601113172 and parameters: {'max_depth': 27, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,847] Trial 97 finished with value: 0.525664811379097 and parameters: {'max_depth': 28, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,882] Trial 98 finished with value: 0.5473098330241187 and parameters: {'max_depth': 29, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,914] Trial 99 finished with value: 0.5200989486703772 and parameters: {'max_depth': 27, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:11,987] Trial 100 finished with value: 0.6147186147186147 and parameters: {'max_depth': 31, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,026] Trial 101 finished with value: 0.5769944341372912 and parameters: {'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,058] Trial 102 finished with value: 0.5732838589981447 and parameters: {'max_depth': 31, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,091] Trial 103 finished with value: 0.5145330859616574 and parameters: {'max_depth': 32, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,123] Trial 104 finished with value: 0.551638837353123 and parameters: {'max_depth': 27, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,155] Trial 105 finished with value: 0.5868893011750155 and parameters: {'max_depth': 25, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,186] Trial 106 finished with value: 0.5658627087198516 and parameters: {'max_depth': 27, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,218] Trial 107 finished with value: 0.5677179962894249 and parameters: {'max_depth': 26, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,255] Trial 108 finished with value: 0.5528756957328386 and parameters: {'max_depth': 29, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,284] Trial 109 finished with value: 0.5485466914038343 and parameters: {'max_depth': 28, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,317] Trial 110 finished with value: 0.5330859616573902 and parameters: {'max_depth': 24, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,348] Trial 111 finished with value: 0.562152133580705 and parameters: {'max_depth': 22, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,382] Trial 112 finished with value: 0.5132962275819418 and parameters: {'max_depth': 31, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,415] Trial 113 finished with value: 0.47371675943104513 and parameters: {'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,446] Trial 114 finished with value: 0.5040197897340755 and parameters: {'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,477] Trial 115 finished with value: 0.6171923314780458 and parameters: {'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,510] Trial 116 finished with value: 0.6029684601113172 and parameters: {'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,544] Trial 117 finished with value: 0.5200989486703772 and parameters: {'max_depth': 26, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,576] Trial 118 finished with value: 0.5708101422387136 and parameters: {'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,613] Trial 119 finished with value: 0.5522572665429808 and parameters: {'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,647] Trial 120 finished with value: 0.562152133580705 and parameters: {'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,682] Trial 121 finished with value: 0.5398886827458256 and parameters: {'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,712] Trial 122 finished with value: 0.5528756957328386 and parameters: {'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,744] Trial 123 finished with value: 0.5683364254792826 and parameters: {'max_depth': 27, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,779] Trial 124 finished with value: 0.5565862708719852 and parameters: {'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,809] Trial 125 finished with value: 0.6202844774273346 and parameters: {'max_depth': 30, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,840] Trial 126 finished with value: 0.5398886827458256 and parameters: {'max_depth': 31, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,876] Trial 127 finished with value: 0.5578231292517006 and parameters: {'max_depth': 30, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,905] Trial 128 finished with value: 0.5392702535559678 and parameters: {'max_depth': 28, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,939] Trial 129 finished with value: 0.5683364254792826 and parameters: {'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:12,972] Trial 130 finished with value: 0.6004947433518862 and parameters: {'max_depth': 26, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,006] Trial 131 finished with value: 0.5893630179344465 and parameters: {'max_depth': 26, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,038] Trial 132 finished with value: 0.6171923314780458 and parameters: {'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,070] Trial 133 finished with value: 0.5126777983920842 and parameters: {'max_depth': 32, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,091] Trial 134 finished with value: 0.14594928880643165 and parameters: {'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,125] Trial 135 finished with value: 0.5460729746444032 and parameters: {'max_depth': 30, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,158] Trial 136 finished with value: 0.5473098330241187 and parameters: {'max_depth': 29, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,192] Trial 137 finished with value: 0.5887445887445888 and parameters: {'max_depth': 28, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,227] Trial 138 finished with value: 0.5683364254792826 and parameters: {'max_depth': 31, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,260] Trial 139 finished with value: 0.6091527520098948 and parameters: {'max_depth': 27, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,291] Trial 140 finished with value: 0.518243661100804 and parameters: {'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,326] Trial 141 finished with value: 0.5083487940630798 and parameters: {'max_depth': 27, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,358] Trial 142 finished with value: 0.5844155844155844 and parameters: {'max_depth': 28, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,391] Trial 143 finished with value: 0.5739022881880025 and parameters: {'max_depth': 29, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,426] Trial 144 finished with value: 0.5856524427952999 and parameters: {'max_depth': 27, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,456] Trial 145 finished with value: 0.575139146567718 and parameters: {'max_depth': 24, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,489] Trial 146 finished with value: 0.5541125541125541 and parameters: {'max_depth': 26, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,523] Trial 147 finished with value: 0.5454545454545454 and parameters: {'max_depth': 32, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,555] Trial 148 finished with value: 0.5367965367965368 and parameters: {'max_depth': 25, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,583] Trial 149 finished with value: 0.4483611626468769 and parameters: {'max_depth': 28, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'criterion': 'entropy'}. Best is trial 25 with value: 0.6233766233766234.
# [I 2025-06-21 19:50:13,584] A new study created in memory with name: RandomForest - Adult Income Prediction
# DecisionTree Best hyperparameters:  {'max_depth': 30, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'criterion': 'gini'}
# [I 2025-06-21 19:50:14,239] Trial 0 finished with value: 0.5850340136054422 and parameters: {'rf_max_depth': 22, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 51}. Best is trial 0 with value: 0.5850340136054422.
# [I 2025-06-21 19:50:15,204] Trial 1 finished with value: 0.5200989486703772 and parameters: {'rf_max_depth': 9, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy', 'rf_n_estimators': 108}. Best is trial 0 with value: 0.5850340136054422.
# [I 2025-06-21 19:50:16,931] Trial 2 finished with value: 0.5590599876314162 and parameters: {'rf_max_depth': 26, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_criterion': 'gini', 'rf_n_estimators': 195}. Best is trial 0 with value: 0.5850340136054422.
# [I 2025-06-21 19:50:19,095] Trial 3 finished with value: 0.5695732838589982 and parameters: {'rf_max_depth': 16, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy', 'rf_n_estimators': 195}. Best is trial 0 with value: 0.5850340136054422.
# [I 2025-06-21 19:50:19,754] Trial 4 finished with value: 0.5807050092764379 and parameters: {'rf_max_depth': 20, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_criterion': 'gini', 'rf_n_estimators': 61}. Best is trial 0 with value: 0.5850340136054422.
# [I 2025-06-21 19:50:20,722] Trial 5 finished with value: 0.33766233766233766 and parameters: {'rf_max_depth': 5, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy', 'rf_n_estimators': 167}. Best is trial 0 with value: 0.5850340136054422.
# [I 2025-06-21 19:50:22,808] Trial 6 finished with value: 0.559678416821274 and parameters: {'rf_max_depth': 14, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy', 'rf_n_estimators': 184}. Best is trial 0 with value: 0.5850340136054422.
# [I 2025-06-21 19:50:23,778] Trial 7 finished with value: 0.5299938157081014 and parameters: {'rf_max_depth': 14, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': 'log2', 'rf_criterion': 'gini', 'rf_n_estimators': 121}. Best is trial 0 with value: 0.5850340136054422.
# [I 2025-06-21 19:50:24,453] Trial 8 finished with value: 0.36363636363636365 and parameters: {'rf_max_depth': 7, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_criterion': 'entropy', 'rf_n_estimators': 117}. Best is trial 0 with value: 0.5850340136054422.
# [I 2025-06-21 19:50:25,430] Trial 9 finished with value: 0.5732838589981447 and parameters: {'rf_max_depth': 31, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': 'log2', 'rf_criterion': 'gini', 'rf_n_estimators': 102}. Best is trial 0 with value: 0.5850340136054422.
# [I 2025-06-21 19:50:26,106] Trial 10 finished with value: 0.5912183055040198 and parameters: {'rf_max_depth': 23, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 52}. Best is trial 10 with value: 0.5912183055040198.
# [I 2025-06-21 19:50:26,836] Trial 11 finished with value: 0.5856524427952999 and parameters: {'rf_max_depth': 23, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 56}. Best is trial 10 with value: 0.5912183055040198.
# [I 2025-06-21 19:50:27,870] Trial 12 finished with value: 0.5967841682127396 and parameters: {'rf_max_depth': 28, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 77}. Best is trial 12 with value: 0.5967841682127396.
# [I 2025-06-21 19:50:29,208] Trial 13 finished with value: 0.5924551638837353 and parameters: {'rf_max_depth': 32, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 81}. Best is trial 12 with value: 0.5967841682127396.
# [I 2025-06-21 19:50:30,543] Trial 14 finished with value: 0.5974025974025974 and parameters: {'rf_max_depth': 32, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 82}. Best is trial 14 with value: 0.5974025974025974.
# [I 2025-06-21 19:50:32,780] Trial 15 finished with value: 0.6004947433518862 and parameters: {'rf_max_depth': 28, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 147}. Best is trial 15 with value: 0.6004947433518862.
# [I 2025-06-21 19:50:34,996] Trial 16 finished with value: 0.5967841682127396 and parameters: {'rf_max_depth': 28, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 145}. Best is trial 15 with value: 0.6004947433518862.
# [I 2025-06-21 19:50:37,260] Trial 17 finished with value: 0.6004947433518862 and parameters: {'rf_max_depth': 32, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 145}. Best is trial 15 with value: 0.6004947433518862.
# [I 2025-06-21 19:50:39,374] Trial 18 finished with value: 0.5998763141620285 and parameters: {'rf_max_depth': 28, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 141}. Best is trial 15 with value: 0.6004947433518862.
# [I 2025-06-21 19:50:41,223] Trial 19 finished with value: 0.5745207173778603 and parameters: {'rf_max_depth': 19, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 153}. Best is trial 15 with value: 0.6004947433518862.
# [I 2025-06-21 19:50:41,788] Trial 20 finished with value: 0.006184291898577613 and parameters: {'rf_max_depth': 2, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 165}. Best is trial 15 with value: 0.6004947433518862.
# [I 2025-06-21 19:50:43,874] Trial 21 finished with value: 0.603586889301175 and parameters: {'rf_max_depth': 28, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 140}. Best is trial 21 with value: 0.603586889301175.
# [I 2025-06-21 19:50:45,783] Trial 22 finished with value: 0.5992578849721707 and parameters: {'rf_max_depth': 25, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 134}. Best is trial 21 with value: 0.603586889301175.
# [I 2025-06-21 19:50:48,196] Trial 23 finished with value: 0.6004947433518862 and parameters: {'rf_max_depth': 29, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 162}. Best is trial 21 with value: 0.603586889301175.
# [I 2025-06-21 19:50:50,321] Trial 24 finished with value: 0.603586889301175 and parameters: {'rf_max_depth': 25, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 131}. Best is trial 21 with value: 0.603586889301175.
# [I 2025-06-21 19:50:52,132] Trial 25 finished with value: 0.5949288806431664 and parameters: {'rf_max_depth': 25, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 131}. Best is trial 21 with value: 0.603586889301175.
# [I 2025-06-21 19:50:54,153] Trial 26 finished with value: 0.5850340136054422 and parameters: {'rf_max_depth': 21, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_criterion': 'entropy', 'rf_n_estimators': 176}. Best is trial 21 with value: 0.603586889301175.
# [I 2025-06-21 19:50:55,445] Trial 27 finished with value: 0.6004947433518862 and parameters: {'rf_max_depth': 26, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 98}. Best is trial 21 with value: 0.603586889301175.
# [I 2025-06-21 19:50:57,433] Trial 28 finished with value: 0.5794681508967223 and parameters: {'rf_max_depth': 18, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 155}. Best is trial 21 with value: 0.603586889301175.
# [I 2025-06-21 19:50:59,147] Trial 29 finished with value: 0.6042053184910328 and parameters: {'rf_max_depth': 30, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 128}. Best is trial 29 with value: 0.6042053184910328.
# [I 2025-06-21 19:51:00,599] Trial 30 finished with value: 0.5998763141620285 and parameters: {'rf_max_depth': 30, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 115}. Best is trial 29 with value: 0.6042053184910328.
# [I 2025-06-21 19:51:02,359] Trial 31 finished with value: 0.5949288806431664 and parameters: {'rf_max_depth': 27, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini', 'rf_n_estimators': 130}. Best is trial 29 with value: 0.6042053184910328.
# ...
# [I 2025-06-21 20:52:41,834] Trial 105 finished with value: 0.6833642547928263 and parameters: {'bayes_var_smoothing': 1.894221659005702e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 115}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:52:43,302] Trial 106 finished with value: 0.686456400742115 and parameters: {'bayes_var_smoothing': 1.7860669428000604e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 123}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:52:44,731] Trial 107 finished with value: 0.6852195423623995 and parameters: {'bayes_var_smoothing': 1.483919852442559e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 123}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:52:46,201] Trial 108 finished with value: 0.6883116883116883 and parameters: {'bayes_var_smoothing': 1.7278258511067362e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 122}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:52:47,744] Trial 109 finished with value: 0.6592455163883735 and parameters: {'bayes_var_smoothing': 1.6159122813300891e-09, 'xgb_max_depth': 5, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 117}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:52:49,425] Trial 110 finished with value: 0.6277056277056277 and parameters: {'bayes_var_smoothing': 3.4082224180164933e-09, 'xgb_max_depth': 5, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 127}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:52:50,858] Trial 111 finished with value: 0.6895485466914039 and parameters: {'bayes_var_smoothing': 1.8964491263512654e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 122}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:52:52,304] Trial 112 finished with value: 0.6740878169449598 and parameters: {'bayes_var_smoothing': 2.128347228508292e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 120}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:52:54,119] Trial 113 finished with value: 0.6413110698824984 and parameters: {'bayes_var_smoothing': 1.0725004668926303e-09, 'xgb_max_depth': 7, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 112}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:52:55,748] Trial 114 finished with value: 0.629560915275201 and parameters: {'bayes_var_smoothing': 4.362507991761713e-09, 'xgb_max_depth': 5, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 122}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:52:57,197] Trial 115 finished with value: 0.6691403834260977 and parameters: {'bayes_var_smoothing': 2.947384328339821e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 126}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:52:58,400] Trial 116 finished with value: 0.6586270871985158 and parameters: {'bayes_var_smoothing': 1.37291390160979e-09, 'xgb_max_depth': 2, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 132}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:00,378] Trial 117 finished with value: 0.6654298082869512 and parameters: {'bayes_var_smoothing': 7.987133330993066e-10, 'xgb_max_depth': 6, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 139}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:01,787] Trial 118 finished with value: 0.6876932591218305 and parameters: {'bayes_var_smoothing': 7.2872519304167135e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 115}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:03,307] Trial 119 finished with value: 0.658008658008658 and parameters: {'bayes_var_smoothing': 6.081361399755964e-09, 'xgb_max_depth': 5, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 115}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:04,750] Trial 120 finished with value: 0.6858379715522572 and parameters: {'bayes_var_smoothing': 9.112893158518731e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 3, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 119}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:06,050] Trial 121 finished with value: 0.6759431045145331 and parameters: {'bayes_var_smoothing': 8.687418454648979e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 3, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 107}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:07,334] Trial 122 finished with value: 0.6598639455782312 and parameters: {'bayes_var_smoothing': 1.4127659429913127e-08, 'xgb_max_depth': 3, 'xgb_min_samples_split': 4, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 120}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:08,914] Trial 123 finished with value: 0.6802721088435374 and parameters: {'bayes_var_smoothing': 4.105499004148712e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 2, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 128}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:10,625] Trial 124 finished with value: 0.6536796536796536 and parameters: {'bayes_var_smoothing': 2.5836296513239427e-09, 'xgb_max_depth': 6, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 113}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:11,719] Trial 125 finished with value: 0.6406926406926406 and parameters: {'bayes_var_smoothing': 8.840702187538627e-10, 'xgb_max_depth': 2, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 118}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:12,953] Trial 126 finished with value: 0.6784168212739641 and parameters: {'bayes_var_smoothing': 1.9468156930361025e-09, 'xgb_max_depth': 3, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 110}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:14,552] Trial 127 finished with value: 0.6369820655534941 and parameters: {'bayes_var_smoothing': 1.9637903314225956e-08, 'xgb_max_depth': 5, 'xgb_min_samples_split': 3, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 123}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:16,671] Trial 128 finished with value: 0.6444032158317873 and parameters: {'bayes_var_smoothing': 7.227242838534939e-09, 'xgb_max_depth': 7, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 128}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:18,194] Trial 129 finished with value: 0.6573902288188003 and parameters: {'bayes_var_smoothing': 5.25691262164207e-09, 'xgb_max_depth': 5, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 115}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:19,655] Trial 130 finished with value: 0.6802721088435374 and parameters: {'bayes_var_smoothing': 3.151853649489068e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 3, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 121}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:21,203] Trial 131 finished with value: 0.6549165120593692 and parameters: {'bayes_var_smoothing': 1.5771845334702483e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 136}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:22,585] Trial 132 finished with value: 0.6654298082869512 and parameters: {'bayes_var_smoothing': 1.1546150485625612e-08, 'xgb_max_depth': 3, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 132}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:24,201] Trial 133 finished with value: 0.6512059369202227 and parameters: {'bayes_var_smoothing': 2.2165280996664392e-09, 'xgb_max_depth': 5, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 125}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:25,391] Trial 134 finished with value: 0.6641929499072357 and parameters: {'bayes_var_smoothing': 5.715195027428165e-09, 'xgb_max_depth': 2, 'xgb_min_samples_split': 4, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 130}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:26,768] Trial 135 finished with value: 0.6771799628942486 and parameters: {'bayes_var_smoothing': 3.9309729503110996e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 8, 'xgb_min_samples_leaf': 4, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 117}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:28,093] Trial 136 finished with value: 0.6672850958565244 and parameters: {'bayes_var_smoothing': 9.022270483040375e-09, 'xgb_max_depth': 3, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 126}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:29,989] Trial 137 finished with value: 0.6505875077303649 and parameters: {'bayes_var_smoothing': 6.234493199016315e-10, 'xgb_max_depth': 6, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 135}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:31,453] Trial 138 finished with value: 0.6827458256029685 and parameters: {'bayes_var_smoothing': 3.8292842737286494e-10, 'xgb_max_depth': 4, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 122}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:32,632] Trial 139 finished with value: 0.6691403834260977 and parameters: {'bayes_var_smoothing': 9.838413576386515e-10, 'xgb_max_depth': 3, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 110}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:34,097] Trial 140 finished with value: 0.686456400742115 and parameters: {'bayes_var_smoothing': 2.5852726537849433e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 121}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:35,495] Trial 141 finished with value: 0.6740878169449598 and parameters: {'bayes_var_smoothing': 3.0885523989340123e-10, 'xgb_max_depth': 4, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 120}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:37,163] Trial 142 finished with value: 0.6493506493506493 and parameters: {'bayes_var_smoothing': 3.740176114854118e-10, 'xgb_max_depth': 5, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 125}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:38,276] Trial 143 finished with value: 0.6592455163883735 and parameters: {'bayes_var_smoothing': 2.9402759910162197e-09, 'xgb_max_depth': 2, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 122}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:39,849] Trial 144 finished with value: 0.6493506493506493 and parameters: {'bayes_var_smoothing': 1.4508942715665793e-09, 'xgb_max_depth': 5, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 116}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:41,318] Trial 145 finished with value: 0.6771799628942486 and parameters: {'bayes_var_smoothing': 4.86749563151293e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 129}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:42,560] Trial 146 finished with value: 0.6611008039579468 and parameters: {'bayes_var_smoothing': 1.7537104230754492e-09, 'xgb_max_depth': 3, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 113}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:44,164] Trial 147 finished with value: 0.6592455163883735 and parameters: {'bayes_var_smoothing': 2.432873978561199e-09, 'xgb_max_depth': 6, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 107}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:45,783] Trial 148 finished with value: 0.6307977736549165 and parameters: {'bayes_var_smoothing': 3.369366118191575e-09, 'xgb_max_depth': 5, 'xgb_min_samples_split': 9, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 119}. Best is trial 87 with value: 0.6914038342609771.
# [I 2025-06-21 20:53:47,279] Trial 149 finished with value: 0.6852195423623995 and parameters: {'bayes_var_smoothing': 7.0140604998961485e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 5, 'xgb_min_samples_leaf': 3, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 131}. Best is trial 87 with value: 0.6914038342609771.
# Stacking Bayes-XGB Best hyperparameters:  {'bayes_var_smoothing': 9.130958327147878e-09, 'xgb_max_depth': 4, 'xgb_min_samples_split': 10, 'xgb_min_samples_leaf': 1, 'xgb_max_features': 'sqrt', 'xgb_criterion': 'entropy', 'xgb_n_estimators': 132}

# %% [markdown]
# ## Evaluation et comparaison des modèles

# %%
# Import des données de test (33% des données totales)
df_adult_test = pd.read_csv("./Data/adult.test", header=None)
df_adult_test.columns = adult_columns

# Pretraitement du set de test avec un preprocesseur fitted
df_adult_test_new, _ = treat_df(df_adult_test, fitted_preprocessor)
X_test, y_test = df_adult_test_new.drop(columns=["income"]), df_adult_test_new["income"]

df_models_res = pd.DataFrame(columns=["name", "accuracy", "recall", "negative recall", "f1", "mae", "rmse"])

for classifier_name, model in best_models.items():
    model.fit(X_train, y_train)
    print(f"\n=== Evaluation du meilleur modèle du classifieur {classifier_name} ===")
    df_models_res.loc[len(df_models_res)] =(classifier_name,) + eval_model(model, X_test, y_test)

df_models_res.style
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object', name='name')
# income
# <=50K.    12435
# >50K.      3846
# Name: count, dtype: int64
# income
# 0    12435
# 1     3846
# Name: count, dtype: int64
#
# === Evaluation du meilleur modèle du classifieur DecisionTree ===
# Accuracy : 0.8389 (the higher the better)
# Recall : 0.5538 (the higher the better) (best for us)
# Negative recall : 0.9271 (the lower the better)
# F1 : 0.6189 (the higher the better)
# MAE : 0.1611 (the lower the better)
# RMSE : 0.1611 (the lower the better)
#
# === Evaluation du meilleur modèle du classifieur RandomForest ===
# Accuracy : 0.8636 (the higher the better)
# Recall : 0.5941 (the higher the better) (best for us)
# Negative recall : 0.9469 (the lower the better)
# F1 : 0.6729 (the higher the better)
# MAE : 0.1364 (the lower the better)
# RMSE : 0.1364 (the lower the better)
#
# === Evaluation du meilleur modèle du classifieur LogisticRegression ===
# Accuracy : 0.8515 (the higher the better)
# Recall : 0.5933 (the higher the better) (best for us)
# Negative recall : 0.9314 (the lower the better)
# F1 : 0.6538 (the higher the better)
# MAE : 0.1485 (the lower the better)
# RMSE : 0.1485 (the lower the better)
#
# === Evaluation du meilleur modèle du classifieur AdaBoosting ===
# Accuracy : 0.8608 (the higher the better)
# Recall : 0.6274 (the higher the better) (best for us)
# Negative recall : 0.9329 (the lower the better)
# F1 : 0.6804 (the higher the better)
# MAE : 0.1392 (the lower the better)
# RMSE : 0.1392 (the lower the better)
#
# === Evaluation du meilleur modèle du classifieur XGBoosting ===
# Accuracy : 0.8710 (the higher the better)
# Recall : 0.6539 (the higher the better) (best for us)
# Negative recall : 0.9382 (the lower the better)
# F1 : 0.7055 (the higher the better)
# MAE : 0.1290 (the lower the better)
# RMSE : 0.1290 (the lower the better)
#
# === Evaluation du meilleur modèle du classifieur Stacking RF-XGB ===
# Accuracy : 0.8677 (the higher the better)
# Recall : 0.6511 (the higher the better) (best for us)
# Negative recall : 0.9347 (the lower the better)
# F1 : 0.6992 (the higher the better)
# MAE : 0.1323 (the lower the better)
# RMSE : 0.1323 (the lower the better)
#
# === Evaluation du meilleur modèle du classifieur KNN ===
# Accuracy : 0.8219 (the higher the better)
# Recall : 0.5663 (the higher the better) (best for us)
# Negative recall : 0.9010 (the lower the better)
# F1 : 0.6004 (the higher the better)
# MAE : 0.1781 (the lower the better)
# RMSE : 0.1781 (the lower the better)
#
# === Evaluation du meilleur modèle du classifieur NaiveBayes ===
# Accuracy : 0.4858 (the higher the better)
# Recall : 0.9576 (the higher the better) (best for us)
# Negative recall : 0.3398 (the lower the better)
# F1 : 0.4680 (the higher the better)
# MAE : 0.5142 (the lower the better)
# RMSE : 0.5142 (the lower the better)
#
# === Evaluation du meilleur modèle du classifieur SVM ===
# Accuracy : 0.8466 (the higher the better)
# Recall : 0.6326 (the higher the better) (best for us)
# Negative recall : 0.9127 (the lower the better)
# F1 : 0.6608 (the higher the better)
# MAE : 0.1534 (the lower the better)
# RMSE : 0.1534 (the lower the better)
#
# === Evaluation du meilleur modèle du classifieur KMeans ===
# Accuracy : 0.2772 (the higher the better)
# Recall : 0.4230 (the higher the better) (best for us)
# Negative recall : 0.2321 (the lower the better)
# F1 : 0.2166 (the higher the better)
# MAE : 0.7228 (the lower the better)
# RMSE : 0.7228 (the lower the better)
#
# === Evaluation du meilleur modèle du classifieur Stacking Bayes-XGB ===
# Accuracy : 0.8700 (the higher the better)
# Recall : 0.6724 (the higher the better) (best for us)
# Negative recall : 0.9312 (the lower the better)
# F1 : 0.7097 (the higher the better)
# MAE : 0.1300 (the lower the better)
# RMSE : 0.1300 (the lower the better)
# <style type="text/css">
# </style>
# <table id="T_d2c0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2c0b_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_d2c0b_level0_col1" class="col_heading level0 col1" >accuracy</th>
#       <th id="T_d2c0b_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_d2c0b_level0_col3" class="col_heading level0 col3" >negative recall</th>
#       <th id="T_d2c0b_level0_col4" class="col_heading level0 col4" >f1</th>
#       <th id="T_d2c0b_level0_col5" class="col_heading level0 col5" >mae</th>
#       <th id="T_d2c0b_level0_col6" class="col_heading level0 col6" >rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2c0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2c0b_row0_col0" class="data row0 col0" >DecisionTree</td>
#       <td id="T_d2c0b_row0_col1" class="data row0 col1" >0.838892</td>
#       <td id="T_d2c0b_row0_col2" class="data row0 col2" >0.553822</td>
#       <td id="T_d2c0b_row0_col3" class="data row0 col3" >0.927061</td>
#       <td id="T_d2c0b_row0_col4" class="data row0 col4" >0.618916</td>
#       <td id="T_d2c0b_row0_col5" class="data row0 col5" >0.161108</td>
#       <td id="T_d2c0b_row0_col6" class="data row0 col6" >0.161108</td>
#     </tr>
#     <tr>
#       <th id="T_d2c0b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2c0b_row1_col0" class="data row1 col0" >RandomForest</td>
#       <td id="T_d2c0b_row1_col1" class="data row1 col1" >0.863583</td>
#       <td id="T_d2c0b_row1_col2" class="data row1 col2" >0.594124</td>
#       <td id="T_d2c0b_row1_col3" class="data row1 col3" >0.946924</td>
#       <td id="T_d2c0b_row1_col4" class="data row1 col4" >0.672949</td>
#       <td id="T_d2c0b_row1_col5" class="data row1 col5" >0.136417</td>
#       <td id="T_d2c0b_row1_col6" class="data row1 col6" >0.136417</td>
#     </tr>
#     <tr>
#       <th id="T_d2c0b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2c0b_row2_col0" class="data row2 col0" >LogisticRegression</td>
#       <td id="T_d2c0b_row2_col1" class="data row2 col1" >0.851545</td>
#       <td id="T_d2c0b_row2_col2" class="data row2 col2" >0.593344</td>
#       <td id="T_d2c0b_row2_col3" class="data row2 col3" >0.931403</td>
#       <td id="T_d2c0b_row2_col4" class="data row2 col4" >0.653775</td>
#       <td id="T_d2c0b_row2_col5" class="data row2 col5" >0.148455</td>
#       <td id="T_d2c0b_row2_col6" class="data row2 col6" >0.148455</td>
#     </tr>
#     <tr>
#       <th id="T_d2c0b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d2c0b_row3_col0" class="data row3 col0" >AdaBoosting</td>
#       <td id="T_d2c0b_row3_col1" class="data row3 col1" >0.860758</td>
#       <td id="T_d2c0b_row3_col2" class="data row3 col2" >0.627405</td>
#       <td id="T_d2c0b_row3_col3" class="data row3 col3" >0.932931</td>
#       <td id="T_d2c0b_row3_col4" class="data row3 col4" >0.680389</td>
#       <td id="T_d2c0b_row3_col5" class="data row3 col5" >0.139242</td>
#       <td id="T_d2c0b_row3_col6" class="data row3 col6" >0.139242</td>
#     </tr>
#     <tr>
#       <th id="T_d2c0b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d2c0b_row4_col0" class="data row4 col0" >XGBoosting</td>
#       <td id="T_d2c0b_row4_col1" class="data row4 col1" >0.871015</td>
#       <td id="T_d2c0b_row4_col2" class="data row4 col2" >0.653926</td>
#       <td id="T_d2c0b_row4_col3" class="data row4 col3" >0.938158</td>
#       <td id="T_d2c0b_row4_col4" class="data row4 col4" >0.705470</td>
#       <td id="T_d2c0b_row4_col5" class="data row4 col5" >0.128985</td>
#       <td id="T_d2c0b_row4_col6" class="data row4 col6" >0.128985</td>
#     </tr>
#     <tr>
#       <th id="T_d2c0b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d2c0b_row5_col0" class="data row5 col0" >Stacking RF-XGB</td>
#       <td id="T_d2c0b_row5_col1" class="data row5 col1" >0.867699</td>
#       <td id="T_d2c0b_row5_col2" class="data row5 col2" >0.651066</td>
#       <td id="T_d2c0b_row5_col3" class="data row5 col3" >0.934700</td>
#       <td id="T_d2c0b_row5_col4" class="data row5 col4" >0.699246</td>
#       <td id="T_d2c0b_row5_col5" class="data row5 col5" >0.132301</td>
#       <td id="T_d2c0b_row5_col6" class="data row5 col6" >0.132301</td>
#     </tr>
#     <tr>
#       <th id="T_d2c0b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d2c0b_row6_col0" class="data row6 col0" >KNN</td>
#       <td id="T_d2c0b_row6_col1" class="data row6 col1" >0.821940</td>
#       <td id="T_d2c0b_row6_col2" class="data row6 col2" >0.566303</td>
#       <td id="T_d2c0b_row6_col3" class="data row6 col3" >0.901005</td>
#       <td id="T_d2c0b_row6_col4" class="data row6 col4" >0.600414</td>
#       <td id="T_d2c0b_row6_col5" class="data row6 col5" >0.178060</td>
#       <td id="T_d2c0b_row6_col6" class="data row6 col6" >0.178060</td>
#     </tr>
#     <tr>
#       <th id="T_d2c0b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d2c0b_row7_col0" class="data row7 col0" >NaiveBayes</td>
#       <td id="T_d2c0b_row7_col1" class="data row7 col1" >0.485781</td>
#       <td id="T_d2c0b_row7_col2" class="data row7 col2" >0.957618</td>
#       <td id="T_d2c0b_row7_col3" class="data row7 col3" >0.339847</td>
#       <td id="T_d2c0b_row7_col4" class="data row7 col4" >0.468039</td>
#       <td id="T_d2c0b_row7_col5" class="data row7 col5" >0.514219</td>
#       <td id="T_d2c0b_row7_col6" class="data row7 col6" >0.514219</td>
#     </tr>
#     <tr>
#       <th id="T_d2c0b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d2c0b_row8_col0" class="data row8 col0" >SVM</td>
#       <td id="T_d2c0b_row8_col1" class="data row8 col1" >0.846570</td>
#       <td id="T_d2c0b_row8_col2" class="data row8 col2" >0.632605</td>
#       <td id="T_d2c0b_row8_col3" class="data row8 col3" >0.912746</td>
#       <td id="T_d2c0b_row8_col4" class="data row8 col4" >0.660782</td>
#       <td id="T_d2c0b_row8_col5" class="data row8 col5" >0.153430</td>
#       <td id="T_d2c0b_row8_col6" class="data row8 col6" >0.153430</td>
#     </tr>
#     <tr>
#       <th id="T_d2c0b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d2c0b_row9_col0" class="data row9 col0" >KMeans</td>
#       <td id="T_d2c0b_row9_col1" class="data row9 col1" >0.277194</td>
#       <td id="T_d2c0b_row9_col2" class="data row9 col2" >0.423037</td>
#       <td id="T_d2c0b_row9_col3" class="data row9 col3" >0.232087</td>
#       <td id="T_d2c0b_row9_col4" class="data row9 col4" >0.216616</td>
#       <td id="T_d2c0b_row9_col5" class="data row9 col5" >0.722806</td>
#       <td id="T_d2c0b_row9_col6" class="data row9 col6" >0.722806</td>
#     </tr>
#     <tr>
#       <th id="T_d2c0b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d2c0b_row10_col0" class="data row10 col0" >Stacking Bayes-XGB</td>
#       <td id="T_d2c0b_row10_col1" class="data row10 col1" >0.870033</td>
#       <td id="T_d2c0b_row10_col2" class="data row10 col2" >0.672387</td>
#       <td id="T_d2c0b_row10_col3" class="data row10 col3" >0.931162</td>
#       <td id="T_d2c0b_row10_col4" class="data row10 col4" >0.709660</td>
#       <td id="T_d2c0b_row10_col5" class="data row10 col5" >0.129967</td>
#       <td id="T_d2c0b_row10_col6" class="data row10 col6" >0.129967</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Courbe ROC

# %% [markdown]
# Courbe ROC des modèles.

# %%
from math import ceil
from sklearn.metrics import roc_curve, auc

# Number of models
num_models = len(best_models)
rows = ceil(num_models / 2)  # Calculate the number of rows needed

plt.figure(figsize=(12, 6 * rows))

for i, (classifier_name, model) in enumerate(best_models.items(), start=1):
    # Modele de clustering
    if classifier_name == "KMeans":
        continue
    # Prédictions des probabilités pour la classe positive
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    # Calcul des FPR, TPR et seuils
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
    # Calcul de l'AUC
    roc_auc = auc(fpr, tpr)
    # Subplot for each ROC curve
    plt.subplot(rows, 2, i)
    plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=2)  # Ligne diagonale
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title(f'{classifier_name} - ROC Curve')
    plt.legend(loc='lower right')
    plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# Comparaisons des courbes ROC pour les modèles XGBoosting, AdaBoosting, RandomForest

# %%
colors = ['red', 'orange', 'blue']
target_models = ["XGBoosting", "AdaBoosting", "RandomForest"]

plt.rcParams['text.usetex'] = False

for i, classifier_name in enumerate(target_models):
    model = best_models[classifier_name]
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=colors[i], lw=2, label=f'{classifier_name} ROC curve (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=2)
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('XGB, AdaBoost & Random Forest - ROC Curve')
plt.legend(loc='lower right')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ### Courbe de précision-rappel

# %% [markdown]
# Courbes de précision-recall des modèles.

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Number of models
num_models = len(best_models)
rows = ceil(num_models / 2)  # Calculate the number of rows needed

plt.figure(figsize=(12, 6 * rows))

for i, (classifier_name, model) in enumerate(best_models.items(), start=1):
    if classifier_name == "KMeans":
        continue
    # Prédictions des probabilités pour la classe positive
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    # Calcul de la precision du rappel, et des seuils
    precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)
    # Calcul de la moyenne de précision
    avg_precision = average_precision_score(y_test, y_pred_proba)
    # Calcul de la proportion de la classe positive dans les données de test
    positive_class_proportion = y_test.mean()
    # Calcul de l'AUC pour la courbe de précision-rappel
    pr_auc = auc(recall, precision)
    # Tracé de la courbe de précision-rappel
    plt.plot(recall, precision, color='blue', lw=2, label=f'Precision-Recall curve (AP = {avg_precision:.2f})')
    # Tracé de la baseline pour la classe positive
    plt.axhline(y=positive_class_proportion, color='red', linestyle='--', label=f'Baseline (Positive Class = {positive_class_proportion:.2f})')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'{classifier_name} - Precision-Recall Curve')
    plt.legend(loc='lower left')
    plt.grid(alpha=0.3)
    plt.show()

plt.tight_layout()
plt.show()

# %% [markdown]
# Comparaison des courbes Precision-Recall pour les modèles : XGB, AdaBoost et Random Forest

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

colors = ['red', 'orange', 'blue']
target_models = ["XGBoosting", "AdaBoosting", "RandomForest"]

for i, classifier_name in enumerate(target_models):
    model = best_models[classifier_name]
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)
    avg_precision = average_precision_score(y_test, y_pred_proba)
    pr_auc = auc(recall, precision)
    plt.plot(recall, precision, color=colors[i], lw=2, label=f'{classifier_name} PR curve (AP = {avg_precision:.2f})')

# Baseline: proportion de la classe positive
positive_class_proportion = y_test.mean()
plt.axhline(y=positive_class_proportion, color='gray', linestyle='--', label=f'Baseline (Positive Class = {positive_class_proportion:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('XGB, AdaBoost & Random Forest - Precision-Recall Curve')
plt.legend(loc='lower left')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ### Visualisation des modèles de clustering

# %%
kmeans = best_models["KMeans"]
from sklearn.decomposition import PCA

# Reduce dimensions using PCA
pca = PCA(n_components=2)
X_test_2d = pca.fit_transform(X_test)

# Predict cluster labels
kmeans = best_models["KMeans"]
clusters = kmeans.predict(X_test)

# Plot the clusters
plt.figure(figsize=(10, 8))
sns.scatterplot(
    x=X_test_2d[:, 0],
    y=X_test_2d[:, 1],
    hue=clusters,
    alpha=0.8,
    legend='full'
)
plt.title('KMeans Clustering Visualization')
plt.xlabel('PCA Dimension 1')
plt.ylabel('PCA Dimension 2')
plt.legend(title='Cluster')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## Visualisation UMAP

# %%
# import umap.umap_ as umap
#
# # UMAP reduction
# reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42)
# embedding_2d = reducer.fit_transform(X_test)
#
# plt.figure(figsize=(10, 8))
# scatter = plt.scatter(
#     embedding_2d[:, 0], embedding_2d[:, 1],
#     c=y_test, cmap='Spectral', s=10, alpha=0.7
# )
# plt.colorbar(scatter, label='Digit Label')
# plt.title('UMAP Projection of Model Embeddings')
# plt.xlabel('UMAP 1')
# plt.ylabel('UMAP 2')
# plt.grid(True)
# plt.show()

# %%
cm = confusion_matrix(y_test, best_models["XGBoosting"].predict(X_test))
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['<=50K', '>50K'], yticklabels=['<=50K', '>50K'])
# Out:
# <Axes: >
